# %% [markdown]
# # relationship between age and sleep duration

# %%
#required libraries for data science
#importing numpy pandas mathplot and other methods
import pandas as pd #for data manipulation
import numpy as np #scietificc calculation
import matplotlib.pyplot as plt #for data visualization
# %matplotlib inline
import seaborn as sns #for visualization, caption , similat to matplot but advanced

# %%
df= pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
# quick look to dataset
df.head(30)
#column can be said as feature

#df.tail(3) # displays beginning from bottom of the data set
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# ...

# %%
#Print summary statistics
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
#Inspect missing values in the dataset
print(df.isnull().values.sum())
#Replace the ' ' s wiwth NaN
df=df.replace("",np.NaN)
#Impute the missing values with mean imputation
df=df.fillna(df.mean())
#count the number of NaNs is the dataset to verify
print(df.isnull().values.sum())
# Out:
# 0
# 0

# %% [markdown]
# This data set doenot has any missing values. We can start performing EDA

# %%
#seaborn histogram
sns.distplot(df['Age'],hist=True, kde=False,bins=12,color='blue',hist_kws={'edgecolor':'black'})
#Add labels
plt.title('Age count')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The above title shows the histogram of age count

# %%
#seaborn Scatterplot
sns.scatterplot(x=df['Sleep Duration'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Sleep Duration', ylabel='Age'>

# %%
#line plot
sns.lineplot(x='Sleep Duration',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Sleep Duration', ylabel='Age'>

# %% [markdown]
# the above graph shows the relationship between sleep duraion and age

# %%
#box plot
sns.boxplot(y='Age',data=df,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %% [markdown]
# the above box plot shows that majority of men are aged between 30 to 45 and women between 40 to 55

# %%
#heat map pearson correlation matrix
corrmat=df.corr()
f,ax=plt.subplots(figsize=(16,12))
sns.heatmap(corrmat,vmax=0.8,square=True);

# %% [markdown]
# The above figure is pearson correlation matrix which shows "How each column are corelated to each other
#
# Here, Light color i.e see right scale 0.8 is highly corelated and darker color below -0.2 is not corelated
#
# This helps in feature selection also

# %%
plt.figure(figsize=(20,20))
plt.title('Pearson Correlation of Features',size=15)
colormap=sns.diverging_palette(10,220,as_cmap=True)
sns.heatmap(df.corr(), 
            cmap=colormap,
            square=True,
            annot=True,
            linewidths=0.1,vmax=1.0,linecolor='white',
            annot_kws={'fontsize':12})
plt.show()

# %% [markdown]
# the above matix is also a corelatin matrix but it is easier to interpret than a heat map
